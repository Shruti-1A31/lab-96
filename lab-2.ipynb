# %%
# Rathod Shruti A.
# 216270307096

'''Write a NumPy program to implement following operation to convert a list of numeric values into a
one-dimensionalNumPy array'''

import numpy as np

a = [1,2,3,4,5]

a1 = np.array(a)
print(a1)

# %%
# Rathod Shruti A.
# 216270307096

'''Write a NumPy program to implement following operation to create a 3x3 matrix with values ranging from 
2 to 10 '''

b = np.arange(2,11)

m = b.reshape(3,3)
print(m)

# %%
# Rathod Shruti A.
# 216270307096

'''Write a NumPy program to implement following operation to append values at the end of an array'''

c = np.array([1,2,3,4,5])
print("Original Array: ",c)

c1 = np.append(c , [6,7,8,9,10])
print("Array after appending: ", c1)

# %%
# Rathod Shruti A.
# 216270307096

'''Write a NumPy program to implement following operation to create another shape from an array without 
changing its data(3*2 to 2*3)'''

d = np.array([[6,5],[4,3],[2,1]])

print("original array:\n",d)

print("\n change direction of array:\n",d.reshape(2,3))

# %%
''' Rathod Shruti A.
     216270307096    '''

'''Write a NumPy program to implement following operation to split an array of 14 elements into 3 arrays, each
with 2, 4, and 8 elements in the original order'''

import numpy as np

x = np.arange(1, 15)
print("Original array:\n",x)
print("After splitting:")

x1,x2,x3,x4 = np.split(x, [2,6,14])
print(x1,x2,x3)

# %%
''' Rathod Shruti A.
     216270307096    '''

'''Write a NumPy program to implement following operation to stack arrays horizontally (column wise)'''

print("\nOriginal arrays:")
x = np.arange(9).reshape(3,3)
y = x*3

print("Array-1",x)
print("Array-2",y)

new_array =  np.hstack((x,y))
print("\nStack arrays in sequence horizontally:\n",new_array)

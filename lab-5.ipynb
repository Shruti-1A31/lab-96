# %%
''' Rathod Shruti A.
     216270307096    '''

'''Write a NumPy program to implement following operation to find the maximum and minimum value of a given 
flattened array'''

import numpy as np

arr1 = np.array([[2,4,6],[7,8,9]])
print("arr1 :\n",arr1)

arr2 = arr1.flatten()
print("\nFlatten a row-major order: \n",arr2)

print("\nmaximum array in flatten array: ",np.max(arr2))
print("minimum array in flatten array: ",np.min(arr2))

# %%
''' Rathod Shruti A.
     216270307096    '''

'''Write a NumPy program to implement following operation to compute the mean, standard deviation, and variance
of a given array along the second axis'''

a = np.arange(9).reshape(3,3)

print("a: \n",a)

print("\n Mean of a along axis=1: ",np.mean(a, axis=1))
print("\n Standard Deviation along axis=1: ",np.std(a, axis=1))
print("\n Variance of a along axis=1: ",np.var(a, axis=1))
